# %% [markdown]
# <a href="https://colab.research.google.com/github/crdiegobeltramo/BeltramoBitcoin/blob/master/CB01_yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 766 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance as yf

lista=["ggal","AAPL","AAPL.BA"]

data = yf.download(lista,auto_adjust=True)

data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                  Close                       High                       Low  \
#                   AAPL AAPL.BA   GGAL        AAPL AAPL.BA  GGAL        AAPL
# Date
# 1980-12-12    0.100039     NaN    NaN    0.100474     NaN   NaN    0.100039
# 1980-12-15    0.094820     NaN    NaN    0.095255     NaN   NaN    0.094820
# 1980-12-16    0.087861     NaN    NaN    0.088296     NaN   NaN    0.087861
# 1980-12-17    0.090035     NaN    NaN    0.090470     NaN   NaN    0.090035
# 1980-12-18    0.092646     NaN    NaN    0.093081     NaN   NaN    0.092646
# ...                ...     ...    ...         ...     ...   ...         ...
# 2022-08-11  168.490005  4817.5  7.850  170.990005  4932.5  7.95  168.190002
# 2022-08-12  172.100006  4924.5  8.070  172.169998  4937.0  8.08  169.399994
# 2022-08-15  173.190002     NaN  8.310  173.389999     NaN  8.31  171.350006
# ...

# %% [markdown]
# ```
# data = yf.download(  tickers list or string as well
# tickers = "SPY AAPL MSFT",
#
#                 use "period" instead of start/end
#                 valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#                 (optional, default is '1mo')
#                 period = "ytd",
#
#                 fetch data by interval (including intraday if period < 60 days)
#                 valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
#                 (optional, default is '1d')
#                 interval = "1m",
#
#                 group by ticker (to access via data['SPY'])
#                 (optional, default is 'column')
#                 group_by = 'ticker',
#
#                 adjust all OHLC automatically
#                 (optional, default is False)
#                 auto_adjust = True,
#
#                 download pre/post regular market hours data
#                 (optional, default is False)
#                 prepost = True,
#
#                 use threads for mass downloading? (True/False/Integer)
#                 (optional, default is True)
#                 threads = True,
#
#                 proxy URL scheme use use when downloading?
#                 (optional, default is None)
#                 proxy = None)
# ```
#
#
#
# auto_adjust
#
#
#
#
# https://github.com/ranaroussi/yfinance

# %%
data = yf.download('GGAL',
                  # start="2022-07-01",
                  # end="2022-07-29",
                  period='5d',
                  interval='1h',
                  #  groupby='ticker',
                   auto_adjust=True)

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                              Open    High     Low   Close  Volume
# 2022-08-11 09:30:00-04:00  7.7200  7.9500  7.7000  7.9201       0
# 2022-08-11 10:30:00-04:00  7.9200  7.9400  7.7050  7.7399   81018
# 2022-08-11 11:30:00-04:00  7.7400  7.8627  7.7400  7.8000  135204
# 2022-08-11 12:30:00-04:00  7.8199  7.8400  7.8000  7.8300   23694
# 2022-08-11 13:30:00-04:00  7.8301  7.9250  7.7950  7.9100   64013
# 2022-08-11 14:30:00-04:00  7.9127  7.9327  7.8400  7.8500   42100
# 2022-08-11 15:30:00-04:00  7.8500  7.8550  7.8100  7.8550   42416
# 2022-08-12 09:30:00-04:00  7.8800  7.9900  7.8050  7.8800   42528
# 2022-08-12 10:30:00-04:00  7.8750  7.9038  7.8501  7.8900   27138
# 2022-08-12 11:30:00-04:00  7.8999  7.9300  7.8650  7.9100   22245
# 2022-08-12 12:30:00-04:00  7.9000  7.9450  7.8900  7.9250   54762
# 2022-08-12 13:30:00-04:00  7.9300  7.9850  7.9150  7.9800   64084
# ...

# %%
import pandas as pd

# data.to_excel("data.xlsx")
data.to_csv("data.csv")

# %%
df=pd.read_excel("data.xlsx",header=0,index_col=0)

df
# Out:
#             Open  High   Low  Close   Volume
# Date
# 2022-07-01  7.01  7.17  6.77   7.16   371400
# 2022-07-05  6.69  6.85  6.49   6.84   896700
# 2022-07-06  6.83  6.90  6.61   6.69   378700
# 2022-07-07  6.98  6.98  6.64   6.69   720900
# 2022-07-08  6.64  6.90  6.63   6.68   599000
# 2022-07-11  6.63  6.70  6.44   6.56   526800
# 2022-07-12  6.50  6.51  6.15   6.49   874200
# 2022-07-13  6.41  6.55  6.23   6.32   644000
# 2022-07-14  6.19  6.30  6.02   6.14  1133300
# 2022-07-15  6.17  6.31  6.04   6.29   499000
# 2022-07-18  6.36  6.54  6.30   6.41   616100
# 2022-07-19  6.48  6.53  6.32   6.33   790400
# 2022-07-20  6.24  6.34  5.99   5.99   984300
# 2022-07-21  6.00  6.01  5.75   5.93   750000
# 2022-07-22  5.99  6.17  5.85   6.16  1206500
# 2022-07-25  6.20  6.57  6.16   6.46   776200
# 2022-07-26  6.41  6.62  6.36   6.49   525600
# 2022-07-27  6.58  6.86  6.26   6.82   862800
# 2022-07-28  6.89  7.47  6.84   7.39  2090800
